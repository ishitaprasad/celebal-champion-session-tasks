# %%
/Volumes/workspace/cle/cle/callcenter.csv

# %%
df = spark.read.csv(
    "/Volumes/workspace/cle/cle/callcenter.csv",
    header=True,
    inferSchema=True
)
df.show()
# Out:
# +-------+-------+----------+-------------------+-----------------+--------------+--------+--------------------------+-------------------+-------------------+
# |Call Id|  Agent|      Date|               Time|            Topic|Answered (Y/N)|Resolved|Speed of answer in seconds|    AvgTalkDuration|Satisfaction rating|
# +-------+-------+----------+-------------------+-----------------+--------------+--------+--------------------------+-------------------+-------------------+
# | ID0001|  Diane|2021-01-01|2026-01-30 09:12:58| Contract related|             Y|       Y|                       109|2026-01-30 00:02:23|                  3|
# | ID0002|  Becky|2021-01-01|2026-01-30 09:12:58|Technical Support|             Y|       N|                        70|2026-01-30 00:04:02|                  3|
# | ID0003|Stewart|2021-01-01|2026-01-30 09:47:31| Contract related|             Y|       Y|                        10|2026-01-30 00:02:11|                  3|
# ...

# %%
df.select("Agent", "Topic").show()
# Out:
# +-------+-----------------+
# |  Agent|            Topic|
# +-------+-----------------+
# |  Diane| Contract related|
# |  Becky|Technical Support|
# |Stewart| Contract related|
# |   Greg| Contract related|
# |  Becky|  Payment related|
# |Stewart|Technical Support|
# |  Diane|  Payment related|
# |  Diane|  Payment related|
# |   Greg|    Admin Support|
# |    Jim|        Streaming|
# |    Joe|  Payment related|
# |   Greg|  Payment related|
# |    Joe|  Payment related|
# | Martha| Contract related|
# |  Becky|    Admin Support|
# |  Becky|    Admin Support|
# |   Greg|Technical Support|
# |  Becky|    Admin Support|
# |    Jim|        Streaming|
# |    Jim| Contract related|
# +-------+-----------------+
# only showing top 20 rows

# %%
df.filter(df["Speed of answer in seconds"] > 50).show()
# Out:
# +-------+-------+----------+-------------------+-----------------+--------------+--------+--------------------------+-------------------+-------------------+
# |Call Id|  Agent|      Date|               Time|            Topic|Answered (Y/N)|Resolved|Speed of answer in seconds|    AvgTalkDuration|Satisfaction rating|
# +-------+-------+----------+-------------------+-----------------+--------------+--------+--------------------------+-------------------+-------------------+
# | ID0001|  Diane|2021-01-01|2026-01-30 09:12:58| Contract related|             Y|       Y|                       109|2026-01-30 00:02:23|                  3|
# | ID0002|  Becky|2021-01-01|2026-01-30 09:12:58|Technical Support|             Y|       N|                        70|2026-01-30 00:04:02|                  3|
# | ID0004|   Greg|2021-01-01|2026-01-30 09:47:31| Contract related|             Y|       Y|                        53|2026-01-30 00:00:37|                  2|
# ...

# %%
# %sql
select * from callcenter limit 5;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
update callcenter set Agent='Ishita' where `Call Id`='ID0001';
select * from callcenter where `Call Id`='ID0001';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Call Id</th><th>Agent</th><th>Date</th><th>Time</th><th>Topic</th><th>Answered (Y/N)</th><th>Resolved</th><th>Speed of answer in seconds</th><th>AvgTalkDuration</th><th>Satisfaction rating</th></tr></thead><tbody><tr><td>ID0001</td><td>Ishita</td><td>2021-01-01</td><td>2025-10-14T09:12:58.000Z</td><td>Contract related</td><td>Y</td><td>Y</td><td>109</td><td>2025-10-14T00:02:23.000Z</td><td>3</td></tr></tbody></table></div>

# %%
# %sql
select Agent from callcenter order by `Speed of answer in seconds`desc;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select Agent, count(*) from callcenter group by Agent;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Agent</th><th>count(*)</th></tr></thead><tbody><tr><td>Becky</td><td>631</td></tr><tr><td>Joe</td><td>593</td></tr><tr><td>Greg</td><td>624</td></tr><tr><td>Dan</td><td>633</td></tr><tr><td>Martha</td><td>638</td></tr><tr><td>Jim</td><td>666</td></tr><tr><td>Stewart</td><td>582</td></tr><tr><td>Diane</td><td>632</td></tr><tr><td>Ishita</td><td>1</td></tr></tbody></table></div>
